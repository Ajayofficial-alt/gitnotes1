# %%
###!pip install mlxtend
import pandas as pd
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %%
ret_data=pd.read_excel("Online Retail.xlsx")
ret_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# #### DATA UNDERSTANDING

# %%
ret_data.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
ret_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
ret_data["Country"].nunique()
# Out:
# 38

# %%
ret_data["Country"].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
ret_data.describe(include="all")
# Out:
#         InvoiceNo StockCode                         Description  \
# count    541909.0    541909                              540455
# unique    25900.0      4070                                4223
# top      573585.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq       1114.0      2313                                2369
# mean          NaN       NaN                                 NaN
# min           NaN       NaN                                 NaN
# 25%           NaN       NaN                                 NaN
# 50%           NaN       NaN                                 NaN
# 75%           NaN       NaN                                 NaN
# max           NaN       NaN                                 NaN
# std           NaN       NaN                                 NaN
#
#              Quantity                    InvoiceDate      UnitPrice  \
# count   541909.000000                         541909  541909.000000
# ...

# %% [markdown]
# #### I want to find out total transaction happened in each country:

# %%
ret_data["Country"].value_counts()
# Out:
# Country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %% [markdown]
# #### Let's build best association for germany as it has more than

# %%
ger_data=ret_data[ret_data["Country"]== "Germany"]
ger_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 1109      536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1110      536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 1111      536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 1112      536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 1113      536527     22244           3 HOOK HANGER MAGIC GARDEN        12
# ...          ...       ...                                  ...       ...
# 541801    581578     22993         SET OF 4 PANTRY JELLY MOULDS        12
# 541802    581578     22907     PACK OF 20 NAPKINS PANTRY DESIGN        12
# 541803    581578     22908        PACK OF 20 NAPKINS RED APPLES        12
# 541804    581578     23215     JINGLE BELL HEART ANTIQUE SILVER        12
# 541805    581578     22736          RIBBON REEL MAKING SNOWMEN         10
#
#                InvoiceDate  UnitPrice  CustomerID  Country
# ...

# %%
ger_data.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
plt.plot(ger_data['Quantity'].head(10),color='green',marker='o',linestyle='dashed')

# %%
ger_data.head(10)
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 1109    536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1110    536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 1111    536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 1112    536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 1113    536527     22244           3 HOOK HANGER MAGIC GARDEN        12
# 1114    536527     22243    5 HOOK HANGER RED MAGIC TOADSTOOL        12
# 1115    536527     47421  ASSORTED COLOUR LIZARD SUCTION HOOK        24
# 1116    536527     20712           JUMBO BAG WOODLAND ANIMALS        10
# 1117    536527     20713                       JUMBO BAG OWLS        10
# 1118    536527     22837           HOT WATER BOTTLE BABUSHKA          4
#
#              InvoiceDate  UnitPrice  CustomerID  Country
# 1109 2010-12-01 13:04:00       2.95     12662.0  Germany
# 1110 2010-12-01 13:04:00       2.55     12662.0  Germany
# ...

# %%
germ_pivotted =pd.pivot_table(data=ger_data,values="Quantity",index='InvoiceNo',columns='Description',aggfunc="sum").fillna(0)
germ_pivotted
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536527                                  0.0                 0.0
# 536840                                  0.0                 0.0
# 536861                                  0.0                 0.0
# 536967                                  0.0                 0.0
# 536983                                  0.0                 0.0
# ...                                     ...                 ...
# C580313                                 0.0                 0.0
# C580714                                 0.0                 0.0
# C580740                                 0.0                 0.0
# C580989                                 0.0                 0.0
# C581409                                 0.0                 0.0
#
# Description   I LOVE LONDON MINI BACKPACK   RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536527                                0.0                       0.0
# ...

# %%
germ_onehot_encoder=germ_pivotted.applymap(lambda x:0 if x==0 else 1)
germ_onehot_encoder
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536527                                    0                   0
# 536840                                    0                   0
# 536861                                    0                   0
# 536967                                    0                   0
# 536983                                    0                   0
# ...                                     ...                 ...
# C580313                                   0                   0
# C580714                                   0                   0
# C580740                                   0                   0
# C580989                                   0                   0
# C581409                                   0                   0
#
# Description   I LOVE LONDON MINI BACKPACK   RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536527                                  0                         0
# ...

# %%
from mlxtend.frequent_patterns import apriori,association_rules

# %%
apriori_data=apriori(df=germ_onehot_encoder,min_support=0.05,use_colnames=True)
apriori_data
# Out:
#      support                                           itemsets
# 0   0.082919                           (6 RIBBONS RUSTIC CHARM)
# 1   0.054726                        (ALARM CLOCK BAKELIKE PINK)
# 2   0.051410                      (CHARLOTTE BAG APPLES DESIGN)
# 3   0.074627                                (GUMBALL COAT RACK)
# 4   0.056385                            (JAM JAR WITH PINK LID)
# 5   0.071310                           (JAM MAKING SET PRINTED)
# 6   0.051410                                 (JUMBO BAG APPLES)
# 7   0.059701                          (JUMBO BAG RED RETROSPOT)
# 8   0.079602                       (JUMBO BAG WOODLAND ANIMALS)
# 9   0.059701                               (LUNCH BAG WOODLAND)
# 10  0.053068                (LUNCH BOX WITH CUTLERY RETROSPOT )
# 11  0.064677                  (PACK OF 72 RETROSPOT CAKE CASES)
# 12  0.094527                   (PLASTERS IN TIN CIRCUS PARADE )
# 13  0.084577                         (PLASTERS IN TIN SPACEBOY)
# ...

# %%
association=association_rules(df=apriori_data,metric='confidence',min_threshold=0.8)
association
# Out:
#                                           antecedents  \
# 0                            (6 RIBBONS RUSTIC CHARM)
# 1                        (JUMBO BAG WOODLAND ANIMALS)
# 2                                (LUNCH BAG WOODLAND)
# 3                    (PLASTERS IN TIN CIRCUS PARADE )
# 4                          (PLASTERS IN TIN SPACEBOY)
# 5                         (PLASTERS IN TIN STRONGMAN)
# 6                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 7                (ROUND SNACK BOXES SET OF 4 FRUITS )
# 8               (ROUND SNACK BOXES SET OF4 WOODLAND )
# 9                               (SPACEBOY LUNCH BOX )
# 10                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 11                           (WOODLAND CHARLOTTE BAG)
# 12      (ROUND SNACK BOXES SET OF 4 FRUITS , POSTAGE)
# 13  (ROUND SNACK BOXES SET OF 4 FRUITS , ROUND SNA...
#
#                               consequents  antecedent support  \
# 0                               (POSTAGE)            0.082919
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(association['support'],association['confidence'],s=association['lift']*100,alpha=0.6)
plt.xlabel("Support")
plt.ylabel("Confidence")
plt.title("Association Rules")
plt.show()

# %% [markdown]
# #### NOTE:
# 1. Association rules is also known as ***market basket analysis or affinity analysis***.

# %% [markdown]
# ##### THE END

# %% [markdown]
# ==========================================================================================================================================
